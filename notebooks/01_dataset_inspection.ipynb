# %% [markdown]
# # Notebook 01: Dataset Inspection & Metadata Analysis
#
# This notebook inspects lunar image products (PNG/TIFF/PDS4), displays sensor dimensions, and visualizes channel characteristics.

# %%
from lunar_correspondence.io.image_loader import load_image
from lunar_correspondence.planetary.instruments import INSTRUMENT_REGISTRY

print("Registered Instruments:", list(INSTRUMENT_REGISTRY.keys()))
