# %% [markdown]
# # Notebook 03: Feature Matching Diagnostics
#
# Interactive inspection of descriptor distances, RANSAC inlier filtering, and grid coverage distribution.

# %%
from lunar_correspondence.features.sift_features import SIFTFeatureExtractor
from lunar_correspondence.matching.descriptor_matcher import DescriptorMatcher

print("Feature modules loaded successfully.")
