# %% [markdown]
# # Notebook 02: Baseline SIFT Image Registration
#
# Demonstrates end-to-end execution of the baseline registration pipeline on a synthetic image pair.

# %%
from lunar_correspondence.pipeline import RegistrationPipeline
from lunar_correspondence.config import load_config

config = load_config("configs/default.yaml")
pipeline = RegistrationPipeline(config)
print("Pipeline initialized:", pipeline.config['pipeline']['name'])
